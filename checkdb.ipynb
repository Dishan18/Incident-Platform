# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("incident.db")

df = pd.read_sql(
    """
    SELECT *
    FROM live_incidents
    ORDER BY created_at DESC
    LIMIT 1
    """,
    conn
)

print(df.T)
# Out:
#                                                                               0
# incident_id                                                      INC-2026-00010
# description                   Oracle production database is unavailable.\nAl...
# application                                                           Oracle DB
# affected_users                                                             8500
# impact_scope                                                         enterprise
# environment                                                          Production
# category                                                               Database
# ai_predicted_team                                                      Database
# ai_predicted_priority                                                        P1
# ai_predicted_resolution_time                                              43.11
# assigned_team                                              Database, Middleware
# ...
