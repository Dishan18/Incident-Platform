# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("incident.db")

df = pd.read_sql(
    """
    SELECT *
    FROM live_incidents
    ORDER BY created_at DESC
    LIMIT 1
    """,
    conn
)

print(df.T)
# Out:
#                                                        0
# incident_id                               INC-2026-00006
# description                   There is packet loss > 10%
# application                                     Firewall
# affected_users                                      1000
# impact_scope                                  department
# environment                                   Production
# category                                        Security
# ai_predicted_team                                Network
# ai_predicted_priority                                 P2
# ai_predicted_resolution_time                      176.45
# assigned_team                                    Network
# priority                                              P2
# root_cause
# status                                            Closed
# team_overridden                                        0
# priority_overridden                                    0
# ...
