# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("incident.db")

df = pd.read_sql(
    """
    SELECT *
    FROM live_incidents
    ORDER BY created_at DESC
    LIMIT 1
    """,
    conn
)

print(df.T)
# Out:
#                                                                      0
# incident_id                                             INC-2026-00008
# description                   VPN connection failed for multiple users
# application                                                VPN Gateway
# affected_users                                                    5000
# impact_scope                                                enterprise
# environment                                                 Production
# category                                                  Connectivity
# ai_predicted_team                                              Network
# ai_predicted_priority                                               P1
# ai_predicted_resolution_time                                    371.44
# assigned_team                                      Network, Middleware
# priority                                                            P1
# ...
